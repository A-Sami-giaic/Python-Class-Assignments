# %% [markdown]
# <a href="https://colab.research.google.com/github/A-Sami-giaic/Python-Class-Assignments/blob/main/Python_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Different ways to create strings:


text1 = 'Single quote string'


text2 = "Double quote string"


text3 = """Triple quote string example"""

#2. Why do we have different quote types?

#Single quotes are great when your text has double quotes inside.

#Double quotes are useful when your text includes apostrophes.

#Triple quotes are useful for writing multiple lines or when your string contains both types of quotes.

#3. Example with both single and double quotes:


quote_mixed = 'He replied, "I don\'t know what to say."'
print(quote_mixed)

#4. Multi-line string for your hobby:


my_hobby = """I really enjoy coding .
It challenges me to think logically and creatively.!"""
print(my_hobby)


 #🔹 Part 2: String Method Exercises

#1. Name formatting practice:


name = "alex parker"

# Make everything uppercase
print(name.upper())

# Make everything lowercase
print(name.lower())

# Capitalize first letter of each part
print(name.title())


#2. Fix and modify a messy string:


text_data = "  Python programming is fun!   "

# Trim spaces
trimmed = text_data.strip()

# Change 'fun' to 'amazing'
updated = trimmed.replace("fun", "amazing")

# Count how many times 'i' appears
i_total = trimmed.count("i")

print(trimmed)
print(updated)
print(f"The letter 'i' appears {i_total} times.")


#3. Work with a sentence:


sentence = "The quick brown fox jumps over the lazy dog"

# Break into words
word_list = sentence.split()

# Join them back with dashes
rejoined = "-".join(word_list)

# Check if sentence begins with 'The'
starts_the = sentence.startswith("The")

# Find the word 'fox'
fox_index = sentence.find("fox")

print(word_list)
print(rejoined)
print("Starts with 'The':", starts_the)
print("Position of 'fox':", fox_index)


#🔹 Part 3: Using F-Strings

user_name = "Alex"
user_age = 18
fav_language = "Python"


print(f"My name is {user_name} and I am {user_age} years old.")


print(f"I'm a fan of {fav_language} – it's the best language!")

# Math inside f-string
print(f"In 5 years, I’ll be {user_age + 5} years old.")


#🔹 Part 4: User Profile Generator with F-Strings and Methods

# Get user input
first = input("What's your first name? ").strip().capitalize()
last = input("Your last name? ").strip().capitalize()
year_of_birth = int(input("Year you were born: "))

# Calculate age
from datetime import datetime
now = datetime.now().year
current_age = now - year_of_birth

# Build username
user_id = first[0].lower() + last.lower() + str(year_of_birth)

#summary
print(f"Profile: {first} {last}, Age: {current_age}, Username: {user_id}")
# Out:
# He replied, "I don't know what to say."
# I really enjoy coding .
# It challenges me to think logically and creatively.!
# ALEX PARKER
# alex parker
# Alex Parker
# Python programming is fun!
# Python programming is amazing!
# The letter 'i' appears 2 times.
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# The-quick-brown-fox-jumps-over-the-lazy-dog
# Starts with 'The': True
# Position of 'fox': 16
# My name is Alex and I am 18 years old.
# I'm a fan of Python – it's the best language!
# In 5 years, I’ll be 23 years old.
# What's your first name? samad
# Your last name? khan
# Year you were born: 2007
# Profile: Samad Khan, Age: 18, Username: skhan2007
